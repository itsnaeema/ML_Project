# %% [markdown]
# <a href="https://colab.research.google.com/github/itsnaeema/ML_Project/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#in seaborn we have already have a data set in seaborn library for study purpose
import seaborn as sns
df=sns.load_dataset("tips")
df#here tip(predict column) is output value and others are input values
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#co-relation-relation between one column to another
#only can find reltion between numerical coulmns cannot find between object
#co-relation higher value is 1 and lower value is 0,some times it can be -ve
df.corr()
# Out:
# <ipython-input-7-95f692a2376b>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#Heat map-to represent graphically correlations
#light colors are highest value and dark colors are lowest values
sns.heatmap(df.corr())#here total bill is hightest in tip
# Out:
# <ipython-input-8-24f97024809a>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())#here total bill is hightest in tip
# <Axes: >

# %%
#joint plot - its like scatter plot but only can pass numerical columns
#used for numerical columns
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')#we can also pass regression line

# %%
sns.jointplot(x='tip',y='size',data=df,kind='hex')#we can also pass heaxagon here dark color mean highest value

# %%
#pair plot-ellam koodi ormich verkan kazhiyum ,like sub plot
sns.pairplot(df,hue="sex")#here highest value in histogram ,then scatter ,lowest marked as point
#also can pass object(hue='')

# %%
sns.pairplot(df,hue="day")

# %%
sns.pairplot(df,hue="time")

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
#countplot()-
sns.countplot(x='sex',data=df,color='pink',hue='day')#to plot other data in same plot
# Out:
# <ipython-input-23-dcdbecd091c4>:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='sex',data=df,color='pink',hue='day')
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=df,color='violet')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
#barplot()-in bar plot we want to pass x and y
sns.barplot(x='total_bill',y='day',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x='total_bill',y='time',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %%
sns.barplot(x='total_bill',y='smoker',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='smoker'>

# %%
#boxplot()
#lowest at bottom
#in boxplot after bottom line 25%,then 50%,then 75%(percentile)
#highest at top(max)
#the circles at top are called outliers
#outliers-wrong datas,if the given data have wrong format,we choose as outliers

sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
#Percentile
#q1 : 25 percentile   q2:50 percentile  q3:75 percentile
#Outliers

# %%
#how to find a percentile(q1,q2,q3)
#3,5,7,1,1,8,4,6
#first we want to sort the data into ascending order from the given data
#1,1,3,4,  5,6,7,8
#then find (median) =4+5/2=4.5  (dividing in 2 part given data,taking,4&5/2(median))if it is ood take middle part,or even do like this
#this is q2:50 percentile

#to calculate q1
#calculate the median of first part(1,1,3,4)
#q1:1+3/2=2 q1=25%

#to calculate q3
#calculate the median of 2nd part(5,6, 7,8)
#q3=6+7/2=6.5

#to remove outlier we should find outliers using IQR
#calculate IQR(InteQuartileRange), Eqn=q3-q1
#q3=6.5 q1=2 ,IQR=6.5-2=4.5

#using this we find outliers,there will be outliers in bottom and top
#to find outliers in Top :(1.5*iqr)+q3=(1.5*4.5)+6.5=13.25
#if any poimt in given data is above 13.25 the it is an outlier
#outliers in bottom:(q1-1.5*iqr)=(2-1.5*4.5)=-4.75
#if any point in given data is below 4.75 then it is an outliers
